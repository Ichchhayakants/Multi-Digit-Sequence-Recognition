# %%
# !ls
# Out:
# 'archive(1).zip'   sample_data

# %%
# !unzip 'archive(1).zip'
# Out:
# Archive:  archive(1).zip
#   inflating: amer_sign2.png
#   inflating: amer_sign3.png
#   inflating: american_sign_language.PNG
#   inflating: sign_mnist_test.csv
#   inflating: sign_mnist_test/sign_mnist_test.csv
#   inflating: sign_mnist_train.csv
#   inflating: sign_mnist_train/sign_mnist_train.csv

# %%
# !ls
# Out:
#  american_sign_language.PNG  'archive(1).zip'   sign_mnist_test.csv
#  amer_sign2.png		      sample_data       sign_mnist_train
#  amer_sign3.png		      sign_mnist_test   sign_mnist_train.csv

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense,Flatten,Conv2D,MaxPool2D,Dropout 
import matplotlib.pyplot as plt
import seaborn as sns 
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np 
import pandas as pd

# %%
## Loading data
train_df = pd.read_csv('sign_mnist_train.csv')
test_df = pd.read_csv("sign_mnist_test.csv")

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27455 entries, 0 to 27454
# Columns: 785 entries, label to pixel784
# dtypes: int64(785)
# memory usage: 164.4 MB

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7172 entries, 0 to 7171
# Columns: 785 entries, label to pixel784
# dtypes: int64(785)
# memory usage: 43.0 MB

# %%
train_df.describe()
# Out:
#               label        pixel1  ...      pixel783      pixel784
# count  27455.000000  27455.000000  ...  27455.000000  27455.000000
# mean      12.318813    145.419377  ...    161.137898    159.824731
# std        7.287552     41.358555  ...     63.610415     64.396846
# min        0.000000      0.000000  ...      0.000000      0.000000
# 25%        6.000000    121.000000  ...    128.000000    125.500000
# 50%       13.000000    150.000000  ...    182.000000    182.000000
# 75%       19.000000    174.000000  ...    204.000000    204.000000
# max       24.000000    255.000000  ...    255.000000    255.000000
#
# [8 rows x 785 columns]

# %%
train_df.head()
# Out:
#    label  pixel1  pixel2  pixel3  ...  pixel781  pixel782  pixel783  pixel784
# 0      3     107     118     127  ...       206       204       203       202
# 1      6     155     157     156  ...       175       103       135       149
# 2      2     187     188     188  ...       198       195       194       195
# 3      2     211     211     212  ...       225       222       229       163
# 4     13     164     167     170  ...       157       163       164       179
#
# [5 rows x 785 columns]

# %%
# extracting train lables
train_label = train_df['label']
# train_label.head()
trainset = train_df.drop(['label'],axis=1)
trainset.head()
# Out:
#    pixel1  pixel2  pixel3  pixel4  ...  pixel781  pixel782  pixel783  pixel784
# 0     107     118     127     134  ...       206       204       203       202
# 1     155     157     156     156  ...       175       103       135       149
# 2     187     188     188     187  ...       198       195       194       195
# 3     211     211     212     212  ...       225       222       229       163
# 4     164     167     170     172  ...       157       163       164       179
#
# [5 rows x 784 columns]

# %%
train_label.head()
# Out:
# 0     3
# 1     6
# 2     2
# 3     2
# 4    13
# Name: label, dtype: int64

# %% [markdown]
# converting the dataframe to numpy array type to be used while training the CNN. The array is converted from 1-D to 3-D which is the required input to the first layer of the CNN. Similar preprocessing is done to the test dataframe.

# %%
X_train = trainset.values 
X_train = trainset.values.reshape(-1,28,28,1)
print(X_train.shape)
# Out:
# (27455, 28, 28, 1)

# %%
test_label = test_df['label']
X_test = test_df.drop(['label'],axis=1)
print(X_test.shape)
X_test.head()
# Out:
# (7172, 784)
#    pixel1  pixel2  pixel3  pixel4  ...  pixel781  pixel782  pixel783  pixel784
# 0     149     149     150     150  ...       106       112       120       107
# 1     126     128     131     132  ...       184       184       182       180
# 2      85      88      92      96  ...       226       225       224       222
# 3     203     205     207     206  ...       230       240       253       255
# 4     188     191     193     195  ...        49        46        46        53
#
# [5 rows x 784 columns]

# %%
# Reshape test set
X_test = X_test.values.reshape(-1,28,28,1)

# %%
# Converting the integer labels to binary form
from sklearn.preprocessing import LabelBinarizer
lb = LabelBinarizer()
y_train = lb.fit_transform(train_label)
y_test = lb.fit_transform(test_label)

# %%
print(X_train.shape,y_train.shape,X_test.shape,y_test.shape)
# Out:
# (27455, 28, 28, 1) (27455, 24) (7172, 28, 28, 1) (7172, 24)

# %% [markdown]
# ## Augmenting the image dataset to generate more data

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   rotation_range = 0,
                                   height_shift_range = 0.2,
                                   width_shift_range = 0.2,
                                   shear_range = 0,
                                   zoom_range = 0.2,
                                   horizontal_flip = True,
                                   fill_mode = 'nearest')
X_test=X_test/255

# %% [markdown]
# ## Visualization of the Datset

# %%
fig, axe = plt.subplots(2,2)
fig.suptitle("Preview of dataset")
axe[0,0].imshow(X_train[0].reshape(28,28),cmap='gray')
axe[0,0].set_title('label: 3 letter: C')

axe[0,1].imshow(X_train[1].reshape(28,28),cmap='gray')
axe[0,0].set_title('label: 6 letter: F')

axe[1,0].imshow(X_train[2].reshape(28,28),cmap='gray')
axe[1,0].set_title('label: 2 letter: B')

axe[1,1].imshow(X_train[4].reshape(28,28),cmap='gray')
axe[1,1].set_title('label: 13 letter: M')
# Out:
# Text(0.5, 1.0, 'label: 13 letter: M')

# %%
# frequency plot of the labels
sns.countplot(train_label)
plt.title("Frequency of each label")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Frequency of each label')

# %% [markdown]
# ## Building the CNN Model

# %%
model = Sequential()
model.add(Conv2D(128,
                 kernel_size=(5,5),
                 strides=1, 
                 padding='same',
                 activation='relu', 
                 input_shape=(28,28,1)))
model.add(MaxPool2D(pool_size=(3,3),
                    strides=2,
                    padding='same'))
model.add(Conv2D(64,
                 kernel_size=(2,2),
                 strides=1,
                 activation='relu',
                 padding='same'))
model.add(MaxPool2D(pool_size = (2,2),
                    strides = 2,
                    padding='same'))
model.add(Conv2D(32, 
                 kernel_size = (2,2),
                 activation = 'relu',
                 padding = 'same'))
model.add(MaxPool2D(pool_size = (2,2),
                    strides = 2,
                    padding = 'same'))
model.add(Flatten())

# %% [markdown]
# # Dense and output layers

# %%
model.add(Dense(units=512, activation='relu'))
model.add(Dropout(rate=0.25))
model.add(Dense(units=24, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 128)       3328
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 128)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 64)        32832
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 32)          8224
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 32)         0
#  2D)
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 512)               262656
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 24)                12312
#
# =================================================================
# Total params: 319,352
# Trainable params: 319,352
# Non-trainable params: 0
# _________________________________________________________________

# %%
## Compile the model 
model.compile(optimizer = 'adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## Training the model

# %%
history=model.fit(train_datagen.flow(X_train,y_train,batch_size=200),
          epochs =35,
          validation_data = (X_test,y_test),
          shuffle = 1
          )
# Out:
# Epoch 1/35
# 138/138 [==============================] - 13s 95ms/step - loss: 0.0596 - accuracy: 0.9788 - val_loss: 0.0030 - val_accuracy: 0.9992
# Epoch 2/35
# 138/138 [==============================] - 13s 94ms/step - loss: 0.0542 - accuracy: 0.9825 - val_loss: 0.0096 - val_accuracy: 0.9958
# Epoch 3/35
# 138/138 [==============================] - 13s 94ms/step - loss: 0.0603 - accuracy: 0.9810 - val_loss: 0.0030 - val_accuracy: 0.9999
# Epoch 4/35
# 138/138 [==============================] - 13s 93ms/step - loss: 0.0586 - accuracy: 0.9808 - val_loss: 0.0074 - val_accuracy: 0.9972
# Epoch 5/35
# 138/138 [==============================] - 13s 94ms/step - loss: 0.0573 - accuracy: 0.9811 - val_loss: 0.0060 - val_accuracy: 0.9978
# Epoch 6/35
# 138/138 [==============================] - 13s 94ms/step - loss: 0.0551 - accuracy: 0.9816 - val_loss: 0.0029 - val_accuracy: 0.9990
# Epoch 7/35
# 138/138 [==============================] - 13s 96ms/step - loss: 0.0531 - accuracy: 0.9823 - val_loss: 0.0213 - val_accuracy: 0.9940
# Epoch 8/35
# 138/138 [==============================] - 13s 94ms/step - loss: 0.0532 - accuracy: 0.9824 - val_loss: 0.0073 - val_accuracy: 0.9972
# Epoch 9/35
# 138/138 [==============================] - 13s 94ms/step - loss: 0.0531 - accuracy: 0.9819 - val_loss: 0.0057 - val_accuracy: 0.9983
# Epoch 10/35
# 138/138 [==============================] - 13s 95ms/step - loss: 0.0564 - accuracy: 0.9813 - val_loss: 0.0184 - val_accuracy: 0.9937
# Epoch 11/35
# 138/138 [==============================] - 13s 95ms/step - loss: 0.0506 - accuracy: 0.9833 - val_loss: 0.0079 - val_accuracy: 0.9979
# Epoch 12/35
# 138/138 [==============================] - 13s 94ms/step - loss: 0.0556 - accuracy: 0.9818 - val_loss: 0.0336 - val_accuracy: 0.9936
# Epoch 13/35
# 138/138 [==============================] - 13s 94ms/step - loss: 0.0531 - accuracy: 0.9822 - val_loss: 0.0033 - val_accuracy: 0.9990
# Epoch 14/35
# 138/138 [==============================] - 13s 95ms/step - loss: 0.0506 - accuracy: 0.9829 - val_loss: 0.0028 - val_accuracy: 0.9997
# Epoch 15/35
# 138/138 [==============================] - 13s 95ms/step - loss: 0.0518 - accuracy: 0.9832 - val_loss: 0.0098 - val_accuracy: 0.9969
# Epoch 16/35
# 138/138 [==============================] - 13s 95ms/step - loss: 0.0526 - accuracy: 0.9819 - val_loss: 0.0182 - val_accuracy: 0.9908
# Epoch 17/35
# 138/138 [==============================] - 13s 94ms/step - loss: 0.0473 - accuracy: 0.9840 - val_loss: 0.0082 - val_accuracy: 0.9976
# Epoch 18/35
# 138/138 [==============================] - 13s 94ms/step - loss: 0.0485 - accuracy: 0.9839 - val_loss: 0.0044 - val_accuracy: 0.9975
# Epoch 19/35
# 138/138 [==============================] - 13s 94ms/step - loss: 0.0500 - accuracy: 0.9828 - val_loss: 0.0081 - val_accuracy: 0.9979
# Epoch 20/35
# 138/138 [==============================] - 13s 94ms/step - loss: 0.0466 - accuracy: 0.9846 - val_loss: 7.9155e-04 - val_accuracy: 1.0000
# Epoch 21/35
# 138/138 [==============================] - 13s 95ms/step - loss: 0.0475 - accuracy: 0.9847 - val_loss: 0.0092 - val_accuracy: 0.9958
# Epoch 22/35
# 138/138 [==============================] - 13s 94ms/step - loss: 0.0520 - accuracy: 0.9831 - val_loss: 0.0012 - val_accuracy: 0.9999
# Epoch 23/35
# 138/138 [==============================] - 13s 95ms/step - loss: 0.0460 - accuracy: 0.9843 - val_loss: 8.6799e-04 - val_accuracy: 1.0000
# Epoch 24/35
# 138/138 [==============================] - 13s 95ms/step - loss: 0.0453 - accuracy: 0.9848 - val_loss: 0.0117 - val_accuracy: 0.9962
# Epoch 25/35
# 138/138 [==============================] - 13s 94ms/step - loss: 0.0455 - accuracy: 0.9850 - val_loss: 2.5008e-04 - val_accuracy: 1.0000
# Epoch 26/35
# 138/138 [==============================] - 13s 94ms/step - loss: 0.0424 - accuracy: 0.9858 - val_loss: 0.0076 - val_accuracy: 0.9965
# Epoch 27/35
# 138/138 [==============================] - 13s 94ms/step - loss: 0.0474 - accuracy: 0.9842 - val_loss: 0.0137 - val_accuracy: 0.9960
# Epoch 28/35
# 138/138 [==============================] - 13s 94ms/step - loss: 0.0429 - accuracy: 0.9862 - val_loss: 0.0059 - val_accuracy: 0.9983
# Epoch 29/35
# 138/138 [==============================] - 13s 94ms/step - loss: 0.0414 - accuracy: 0.9855 - val_loss: 0.0106 - val_accuracy: 0.9961
# Epoch 30/35
# 138/138 [==============================] - 13s 95ms/step - loss: 0.0459 - accuracy: 0.9849 - val_loss: 0.0090 - val_accuracy: 0.9969
# Epoch 31/35
# 138/138 [==============================] - 13s 95ms/step - loss: 0.0433 - accuracy: 0.9864 - val_loss: 0.0098 - val_accuracy: 0.9976
# Epoch 32/35
# 138/138 [==============================] - 13s 95ms/step - loss: 0.0447 - accuracy: 0.9848 - val_loss: 0.0016 - val_accuracy: 0.9997
# Epoch 33/35
# 138/138 [==============================] - 13s 94ms/step - loss: 0.0457 - accuracy: 0.9851 - val_loss: 0.0032 - val_accuracy: 0.9985
# Epoch 34/35
# 138/138 [==============================] - 13s 94ms/step - loss: 0.0468 - accuracy: 0.9852 - val_loss: 0.0132 - val_accuracy: 0.9950
# Epoch 35/35
# 138/138 [==============================] - 13s 95ms/step - loss: 0.0508 - accuracy: 0.9836 - val_loss: 0.0020 - val_accuracy: 0.9992

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model_accuracy')
plt.ylabel('accuracy')
plt.xlabel('epach')
plt.legend(['train','val'],loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model_loss')
plt.ylabel('loss')
plt.xlabel('epach')
plt.legend(['train','val'],loc='upper left')
plt.show()

# %% [markdown]
# ## Evaluating the model

# %%
(ls,acc) = model.evaluate(x = X_test,y = y_test)
# Out:
# 225/225 [==============================] - 1s 6ms/step - loss: 0.0046 - accuracy: 0.9987

# %%
print(f'Model Accuracy = {acc*100}')
# Out:
# Model Accuracy = 99.87451434135437
